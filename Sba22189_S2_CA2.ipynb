# %% [markdown]
# ## Twitter Data - MYSQL

# %%
#!pip install mysql-connector-python

# %%
import mysql.connector

# %%
# Establish a connection to the MySQL server
conn = mysql.connector.connect(
    host='localhost',
    port=3306,
    user='root',
    password='password',
    database='TwitterData'
)

# %%
cursor = conn.cursor()

# %%
import pandas as pd

# Example query to fetch all rows from the "TweetWordCount" table
query = "SELECT * FROM TweetWordCount"
cursor.execute(query)
rows = cursor.fetchall()

# Print the rows to inspect their format
for row in rows:
    print(row[1])

# Split the "tweets" column into separate URL and count columns
split_rows = [(str(tweet[1]).split("\t")[0], int(str(tweet[1]).split("\t")[1])) for tweet in rows]

# Create a DataFrame from the modified data
df = pd.DataFrame(split_rows, columns=["URL", "Count"])

# Display the DataFrame
df
# Out:
# https://t.co/aKGaRUQi56"	2
# https://t.co/aLSOGLO3eZ"	1
# https://t.co/aMSEyB8mng	9
# https://t.co/aMSEyBqvBo	9
# https://t.co/aMgaLKO9Um"	1
# https://t.co/aQ8ompzMtX	6
# https://t.co/aRvpb2Xwj2"	1
# https://t.co/aS2zqt1Ioo"	1
# https://t.co/aSlrS6LPK8	2
# https://t.co/aSoKqxmqgf?	6
# https://t.co/aT76zA9uXa"	21
# https://t.co/aTzfjCKsIO"	1
# https://t.co/aU5VMYpNqC"	2
# https://t.co/aUzC5v3ZSN"	1
# https://t.co/aVihRosS2f	1
# https://t.co/aW64bKezmL	3
# https://t.co/aW7Ia0HWYA	4
# https://t.co/aW8Q6J4nlR"	1
# https://t.co/aWwQzZKNn6"	3
# https://t.co/aWxZUePqGk"	2
# https://t.co/aX34hIM9GG"	1
# https://t.co/aX8PtH0X5u"	3
# https://t.co/aXuYNlytx1"	4
# https://t.co/aZXsUNLgSB"	1
# https://t.co/aa3m6Pyznf	1
# https://t.co/aafP9yoQdY"	1
# https://t.co/aajkvkin5F"	3
# https://t.co/ab9qkjR3U4	3
# https://t.co/ac80kHPIEr"	1
# https://t.co/acqhD4dAqG"	1
# https://t.co/aeI7YxpmNV	1
# https://t.co/aejmbio07H"	1
# https://t.co/aeot2Uu08K"	1
# https://t.co/ag5yqc8UaM"	1
# ...

# %%
#!pip install sqlalchemy
#!pip install mysql.connector
#!pip install pymysql

# %%
import mysql.connector as sql
import pymysql
from sqlalchemy import create_engine

# Set the connection details
UserName = 'root'
Password = 'password'
DatabaseName = 'TwitterData'

# Create the database connection string
db_connection_str = f"mysql+pymysql://{UserName}:{Password}@localhost/{DatabaseName}"

# Create the database connection
db_connection = create_engine(db_connection_str)

import pandas as pd

# Read data from the 'tweets' table
DataFromDB = pd.read_sql('SELECT * FROM tweets', con=db_connection)

DataFromDB.head()
# Out:
#                                               tweets
# 0  RT @fetishfantasylv: Halloween weekend is goin...
# 1    "Viva Las Vegas!! Let's get this party started!
# 2
# 3  #party #partytime #partyfun #vegas #vegasparty...
# 4  "RT @deolbar: LETS HAVE FUN AT DEOL BAR WEDNES...

# %%
import mysql.connector as sql
import pymysql
from sqlalchemy import create_engine

# Set the connection details
UserName = 'root'
Password = 'password'
DatabaseName = 'TwitterData'

# Create the database connection string
db_connection_str = f"mysql+pymysql://{UserName}:{Password}@localhost/{DatabaseName}"

# Create the database connection
db_connection = create_engine(db_connection_str)

import pandas as pd

# Read data from the 'tweets' table
WordsFromDB = pd.read_sql('SELECT * FROM TweetWordCount', con=db_connection)

WordsFromDB.head()
# Out:
#   tweets                        count
# 0   None  https://t.co/aKGaRUQi56"\t2
# 1   None  https://t.co/aLSOGLO3eZ"\t1
# 2   None   https://t.co/aMSEyB8mng\t9
# 3   None   https://t.co/aMSEyBqvBo\t9
# 4   None  https://t.co/aMgaLKO9Um"\t1

# %%
# Split the "count" column into separate "word" and "Frequency" columns
WordsFromDB[['word', 'Frequency']] = WordsFromDB['count'].str.split("\t", expand=True)

# Remove the unnecessary columns
WordsFromDB.drop(columns=['tweets', 'count'], inplace=True)

# Display the modified DataFrame
print(WordsFromDB.head())
# Out:
#                        word Frequency
# 0  https://t.co/aKGaRUQi56"         2
# 1  https://t.co/aLSOGLO3eZ"         1
# 2   https://t.co/aMSEyB8mng         9
# 3   https://t.co/aMSEyBqvBo         9
# 4  https://t.co/aMgaLKO9Um"         1

# %%
# Assuming you have a dataframe named "wordFromDB" with a column named "word"
word_frequency = WordsFromDB['word'].value_counts().reset_index()
word_frequency.columns = ['word', 'frequency']
word_frequency = word_frequency.sort_values('frequency', ascending=False)

# Print the ordered dataframe
print(word_frequency)
# Out:
#                            word  frequency
# 0                             ?        178
# 1                            ??        141
# 2                           ???         92
# 3                          ????         46
# 4                         ?????         20
# ...                         ...        ...
# 8710   https://t.co/VxFd1mh4o6"          1
# 8709   https://t.co/VzeFE2GWBC"          1
# 8708    https://t.co/W0TQXDA1O1          1
# 8707    https://t.co/W0TQXDSb29          1
# 25198  https://t.co/aKAUOPWcyM"          1
#
# [25199 rows x 2 columns]

# %%
#nltk.download('words')

# %%
import pandas as pd
from nltk.corpus import words

# Load the English words corpus from nltk
english_words = set(words.words())

# Assuming you have a dataframe named "wordFromDB" with a column named "word"
filtered_df = WordsFromDB[WordsFromDB['word'].str.lower().isin(english_words)]

# Print the filtered dataframe
print(filtered_df)
# Out:
#                word Frequency
# 2286           huge         3
# 2287         hugely         2
# 2288       huggable         5
# 2290           hula         1
# 2291       humanity         1
# ...             ...       ...
# 23033          hour      None
# 23039         house         6
# 23041  housewarming         4
# 23042           how        20
# 23045       however         1
#
# [4118 rows x 2 columns]

# %%
import pandas as pd

# Assuming you have a dataframe named "wordFromDB" with columns: "word" and "frequency"
ordered_columns = WordsFromDB.sort_values('Frequency', ascending=False)[['word', 'Frequency']]

# Print the ordered columns
print(ordered_columns)
# Out:
#                  word Frequency
# 20768               U        99
# 17129             Buy        99
# 12848  #nomusicnolife        99
# 10679   #eveningdress        99
# 20530              TO        99
# ...               ...       ...
# 23007           homes      None
# 23015            hope      None
# 23019         horizon      None
# 23028         hotspot      None
# 23033            hour      None
#
# [26238 rows x 2 columns]

# %%
print((ordered_columns.head(50)))
# Out:
#                  word Frequency
# 20768               U        99
# 17129             Buy        99
# 12848  #nomusicnolife        99
# 10679   #eveningdress        99
# 20530              TO        99
# 10591            #edm        99
# 12615          #music       986
# 11687     #housemusic        98
# 3834               so        98
# 4666             year        98
# 17745        ENJOY!!!        98
# 10411             #dj       975
# 14349      #takerlama        97
# 15820               @        97
# 13473      #promdress        97
# 4481              was        97
# 21143            Year        96
# 21603           board        96
# 4287            train        96
# 20634        There!!!        96
# 4701             your       954
# 18369            Have        95
# 10678        #evening        95
# 21543            best        95
# 2455          jumping        94
# 12201          #links        94
# 22969         here...        94
# 10510       #drinking        94
# ...

# %%
# Create a new dataframe "Hashtags" with the desired columns
hashtags = ordered_columns[ordered_columns['word'].str.contains('#', regex=False)].copy()
hashtags['hashtag'] = hashtags['word'].str.split('#').str[-1]
hashtags = hashtags[['word', 'hashtag', 'Frequency']]

# Print the "Hashtags" dataframe
print(hashtags)
# Out:
#                    word          hashtag Frequency
# 12848    #nomusicnolife    nomusicnolife        99
# 10679     #eveningdress     eveningdress        99
# 10591              #edm              edm        99
# 12615            #music            music       986
# 11687       #housemusic       housemusic        98
# ...                 ...              ...       ...
# 14289         #surprise         surprise      None
# 14290     #surprisefail     surprisefail      None
# 14863          #wedding          wedding      None
# 14917  #welovefireworks  welovefireworks      None
# 15100                 #                       None
#
# [8357 rows x 3 columns]

# %%
import pandas as pd

# Assuming you have a dataframe named "DataFromDB" with a column named "tweets"

# Calculate word count
DataFromDB['word_count'] = DataFromDB['tweets'].apply(lambda x: len(str(x).split()))

# Calculate character count
DataFromDB['char_count'] = DataFromDB['tweets'].apply(lambda x: len(str(x)))

# Calculate average word length
DataFromDB['avg_word'] = DataFromDB.apply(lambda row: sum(len(word) for word in str(row['tweets']).split()) / row['word_count']
                                          if row['word_count'] != 0 else 0, axis=1)

# Print the updated dataframe
print(DataFromDB)
# Out:
#                                                   tweets  word_count  \
# 0      RT @fetishfantasylv: Halloween weekend is goin...          26
# 1        "Viva Las Vegas!! Let's get this party started!           8
# 2                                                                  0
# 3      #party #partytime #partyfun #vegas #vegasparty...          22
# 4      "RT @deolbar: LETS HAVE FUN AT DEOL BAR WEDNES...          10
# ...                                                  ...         ...
# 36003                                        LETS TECHNO           2
# 36004  #techno #electronicmusic #dj #music #rave #rav...          15
# 36005  "RT @SharedGirlfrie2: Viva Las Vegas!! Let's g...          10
# 36006                                                              0
# 36007  #party #partytime #partyfun #vegas #vegasparty...          22
#
#        char_count   avg_word
# 0             255   8.769231
# 1              47   5.000000
# 2               0   0.000000
# ...

# %%
DataFromDB.describe()
# Out:
#          word_count    char_count      avg_word
# count  36008.000000  36008.000000  36008.000000
# mean       5.248056     45.092285      6.806821
# std        6.462370     59.278256      5.842127
# min        0.000000      0.000000      0.000000
# 25%        1.000000      7.000000      3.333333
# 50%        2.000000     23.000000      5.625000
# 75%        8.000000     55.000000      9.304348
# max       50.000000    255.000000     39.500000

# %%
TweetsStats = DataFromDB.describe()

# %%
#nltk.download('corpora')

# %%
import pandas as pd
from itertools import combinations
from collections import Counter
from textblob import TextBlob

# %%
# Assuming you have a dataframe named "DataFromDB" with a column named "Tweets"
# Set the batch size
batch_size = 500

# Initialize an empty Counter object
co_occurrences = Counter()

# Get the total number of rows in the dataframe
total_rows = len(DataFromDB)

# Iterate over the dataframe in batches
for i in range(0, total_rows, batch_size):
    # Get the current batch of data
    batch = DataFromDB['tweets'].iloc[i:i+batch_size]

    # Extract the words from the current batch
    words = ' '.join(batch).split()

    # Count the co-occurring word pairs in the current batch
    co_occurrences += Counter(list(combinations(words, 2)))

# Get the most common co-occurring word pairs
top_co_occurrences = co_occurrences.most_common()

# Create a new dataframe "CoupledWords" to store the co-occurring word pairs and frequencies
CoupledWords = pd.DataFrame(top_co_occurrences, columns=['CoupledWords', 'Frequency'])

# Print the "CoupledWords" dataframe
print(CoupledWords)
# Out:
#                                                CoupledWords  Frequency
# 0                                          (#party, #party)     290479
# 1                                      (#party, #partytime)     280564
# 2                                      (#partytime, #party)     275091
# 3                                  (#partytime, #partytime)     262241
# 4                                             (#party, "RT)     112128
# ...                                                     ...        ...
# 24375959             (https://t.co/I3bdSoiOkQ", #vegaswife)          1
# 24375960              (https://t.co/I3bdSoiOkQ", #thecosmo)          1
# 24375961              (https://t.co/I3bdSoiOkQ", #bellagio)          1
# 24375962             (https://t.co/I3bdSoiOkQ", #vegaspool)          1
# 24375963  (https://t.co/I3bdSoiOkQ", https://t.co/YKrdvA...          1
#
# [24375964 rows x 2 columns]

# %%
# Specify the file path
file_path = '/home/hduser/Downloads/Twitter_Data_CA2.xlsx'

# Load the Excel file into a DataFrame
df_twitterdata = pd.read_excel(file_path)

# Display the DataFrame
print(df_twitterdata.head())
# Out:
#                      User          Username            UTC Date  \
# 0  🎸GUITARIST ROB JOHNSON  @RobJohnsonShred 2023-05-13 19:38:37
# 1             LETS TECHNO       @TechnoLets 2023-05-13 05:58:55
# 2                ALZKIDZ🔥     @alzkidzmusic 2023-05-12 23:25:48
# 3        Timeless Moments  @TMomPhotography 2023-05-12 22:00:12
# 4       Lost In Marrakech       @lostinkech 2023-05-12 20:27:57
#
#                                                Tweet  Binders  \
# 0  RT @RobJohnsonShred: SHE LOVES BEER 👍🏻😁🍻✅ #bee...      NaN
# 1  RT @TechnoLets: AELVA K “Resurrection”\n\nBeat...      NaN
# 2  RT @TechnoLets: AELVA K “Resurrection”\n\nBeat...      NaN
# 3  Golden Light Over Cocoa Game Cards\nhttps://t....      NaN
# 4  Party until dawn at Theatro. A daring venue th...      NaN
#
#                                            Permalink  Retweet count  \
# 0  https://www.twitter.com/user/status/1657470422...              0
# ...

# %%
df_twitterdata = df_twitterdata.drop('Binders', axis=1)

# %%
#pip install nltk
#nltk.download('vader_lexicon')

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
#nltk.download('vader_lexicon')

# Initialize the SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
def classify_sentiment(tweet):
    sentiment_scores = sia.polarity_scores(tweet)
    compound_score = sentiment_scores['compound']
    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# %%
df_twitterdata['Sentiment'] = df_twitterdata['Tweet'].apply(classify_sentiment)

# %%
print(df_twitterdata.head())
# Out:
#                      User          Username            UTC Date  \
# 0  🎸GUITARIST ROB JOHNSON  @RobJohnsonShred 2023-05-13 19:38:37
# 1             LETS TECHNO       @TechnoLets 2023-05-13 05:58:55
# 2                ALZKIDZ🔥     @alzkidzmusic 2023-05-12 23:25:48
# 3        Timeless Moments  @TMomPhotography 2023-05-12 22:00:12
# 4       Lost In Marrakech       @lostinkech 2023-05-12 20:27:57
#
#                                                Tweet  \
# 0  RT @RobJohnsonShred: SHE LOVES BEER 👍🏻😁🍻✅ #bee...
# 1  RT @TechnoLets: AELVA K “Resurrection”\n\nBeat...
# 2  RT @TechnoLets: AELVA K “Resurrection”\n\nBeat...
# 3  Golden Light Over Cocoa Game Cards\nhttps://t....
# 4  Party until dawn at Theatro. A daring venue th...
#
#                                            Permalink  Retweet count  \
# 0  https://www.twitter.com/user/status/1657470422...              0
# 1  https://www.twitter.com/user/status/1657264136...              0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

sentiment_counts = df_twitterdata['Sentiment'].value_counts()

# Set the style of the plot
sns.set_style('whitegrid')

# Increase the figure size
plt.figure(figsize=(10, 6))

# Create a bar plot with custom colors
ax = sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette=['green', 'red', 'blue'])

ax.set(xlabel='Sentiment', ylabel='Count', title='Sentiment Distribution')

font_prop = fm.FontProperties(weight='bold')

ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop)

# Add data labels to each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom', fontweight='bold')

# Display the plot
plt.show()

# %%
df_twitterdata['Day'] = df_twitterdata['UTC Date'].dt.day_name()
df_twitterdata['Month'] = df_twitterdata['UTC Date'].dt.month

print(df_twitterdata)
# Out:
#                         User          Username            UTC Date  \
# 0     🎸GUITARIST ROB JOHNSON  @RobJohnsonShred 2023-05-13 19:38:37
# 1                LETS TECHNO       @TechnoLets 2023-05-13 05:58:55
# 2                   ALZKIDZ🔥     @alzkidzmusic 2023-05-12 23:25:48
# 3           Timeless Moments  @TMomPhotography 2023-05-12 22:00:12
# 4          Lost In Marrakech       @lostinkech 2023-05-12 20:27:57
# ...                      ...               ...                 ...
# 7717               Carol Alt    @ModelCarolAlt 2022-05-13 12:00:56
# 7718           ShyamG Snacks     @shyamgsnacks 2022-05-13 06:03:17
# 7719          Bawa Gone Goan     @BawaGoneGoan 2022-05-13 05:35:25
# 7720      Party Instyle Shop   @_PartyInStyle_ 2022-05-13 05:06:38
# 7721                    Dino        @Dino_2244 2022-05-13 02:29:26
#
#                                                   Tweet  \
# 0     RT @RobJohnsonShred: SHE LOVES BEER 👍🏻😁🍻✅ #bee...
# ...

# %%
def dayPlot():
    plt.figure(figsize=(12, 6))
    sns.countplot(data=df_twitterdata, x='Day')
    plt.xlabel('Day of Week')
    plt.ylabel('Tweet Count')

    plt.text(0.5, 1.05, 'Tweet Distribution by Day of Week', weight='bold', ha='center', transform=plt.gca().transAxes)

    plt.show()
dayPlot()

# %%
def monthPlot():
    plt.figure(figsize=(12, 6))
    sns.countplot(data=df_twitterdata, x='Month')
    plt.xlabel('Month of tweet')
    plt.ylabel('Tweet Count')

    plt.text(0.5, 1.05, 'Tweet Distribution by Month', weight='bold', ha='center', transform=plt.gca().transAxes)

    plt.show()

monthPlot()

# %% [markdown]
# ## One hot encoding

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# 2023-05-22 20:16:52.099392: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-22 20:16:52.321886: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-22 20:16:52.322644: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-22 20:16:59.287466: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Apply one-hot encoding to the "Sentiment" column
one_hot_encoded = pd.get_dummies(df_twitterdata['Sentiment'])

# Concatenate the one-hot encoded columns with the original DataFrame
df_encoded = pd.concat([df_twitterdata, one_hot_encoded], axis=1)
print(df_encoded)
# Out:
#                         User          Username            UTC Date  \
# 0     🎸GUITARIST ROB JOHNSON  @RobJohnsonShred 2023-05-13 19:38:37
# 1                LETS TECHNO       @TechnoLets 2023-05-13 05:58:55
# 2                   ALZKIDZ🔥     @alzkidzmusic 2023-05-12 23:25:48
# 3           Timeless Moments  @TMomPhotography 2023-05-12 22:00:12
# 4          Lost In Marrakech       @lostinkech 2023-05-12 20:27:57
# ...                      ...               ...                 ...
# 7717               Carol Alt    @ModelCarolAlt 2022-05-13 12:00:56
# 7718           ShyamG Snacks     @shyamgsnacks 2022-05-13 06:03:17
# 7719          Bawa Gone Goan     @BawaGoneGoan 2022-05-13 05:35:25
# 7720      Party Instyle Shop   @_PartyInStyle_ 2022-05-13 05:06:38
# 7721                    Dino        @Dino_2244 2022-05-13 02:29:26
#
#                                                   Tweet  \
# 0     RT @RobJohnsonShred: SHE LOVES BEER 👍🏻😁🍻✅ #bee...
# ...

# %%
#pip install -U scikit-learn

# %%
df = df_encoded[['Tweet', 'Positive', 'Negative', 'Neutral']].copy()

# %%
X = df['Tweet'].values
y = df.drop('Tweet', axis=1).values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
vect = CountVectorizer()
X_train = vect.fit_transform(X_train)
X_test = vect.transform(X_test)

# %%
tfidf = TfidfTransformer()
X_train = tfidf.fit_transform(X_train)
X_test = tfidf.transform(X_test)
X_train = X_train.toarray()
X_test = X_test.toarray()

# %%
model = Sequential()

model.add(Dense(units=12673,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(units=4000,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(units=500,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(units=3, activation='softmax'))

opt=tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

#early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)

# %%
model.fit(x=X_train, y=y_train, batch_size=256, epochs=10, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/10
# 22/22 [==============================] - 55s 2s/step - loss: 0.4994 - accuracy: 0.7865 - val_loss: 0.2833 - val_accuracy: 0.8964
# Epoch 2/10
# 22/22 [==============================] - 52s 2s/step - loss: 0.0936 - accuracy: 0.9669 - val_loss: 0.3933 - val_accuracy: 0.9145
# Epoch 3/10
# 22/22 [==============================] - 52s 2s/step - loss: 0.0299 - accuracy: 0.9880 - val_loss: 0.3749 - val_accuracy: 0.9215
# Epoch 4/10
# 22/22 [==============================] - 52s 2s/step - loss: 0.0172 - accuracy: 0.9946 - val_loss: 0.4124 - val_accuracy: 0.9301
# Epoch 5/10
# 22/22 [==============================] - 52s 2s/step - loss: 0.0104 - accuracy: 0.9961 - val_loss: 0.4462 - val_accuracy: 0.9271
# Epoch 6/10
# 22/22 [==============================] - 52s 2s/step - loss: 0.0128 - accuracy: 0.9956 - val_loss: 0.4612 - val_accuracy: 0.9275
# Epoch 7/10
# ...

# %%
model_score = model.evaluate(X_test, y_test, batch_size=64, verbose=1)
print('Test accuracy:', model_score[1])
# Out:
# 37/37 [==============================] - 4s 103ms/step - loss: 0.4389 - accuracy: 0.9288
# Test accuracy: 0.9287872314453125

# %%
preds = model.predict(X_test)
preds
# Out:
# 73/73 [==============================] - 6s 77ms/step
# array([[9.9999994e-01, 1.3533782e-09, 8.1005574e-10],
#        [3.9067796e-10, 9.9999994e-01, 1.1532864e-16],
#        [9.9999994e-01, 2.3165221e-11, 2.1758734e-10],
#        ...,
#        [3.1916457e-07, 2.8743676e-09, 9.9999964e-01],
#        [9.9999893e-01, 3.9819824e-07, 6.9171773e-07],
#        [1.0000000e+00, 8.2136929e-11, 1.4435263e-10]], dtype=float32)

# %%
preds.shape
# Out:
# (2317, 3)

# %% [markdown]
# ## Time Series Analysis

# %%
df_timeseries = df_twitterdata.copy()

# %%
df_timeseries['UTC Date'] = pd.to_datetime(df_timeseries['UTC Date'])

# %%
df_timeseries.set_index('UTC Date', inplace=True)

# %%
tweet_frequency = df_timeseries.resample('D').size()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
tweet_frequency.plot()
plt.xlabel('Date')
plt.ylabel('Tweet Frequency')
plt.title('Frequency of Tweets over Time')
plt.show()

# %% [markdown]
# # # Predictions

# %%
#pip install prophet
# !pip install plotly ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from prophet import Prophet

# %%
df_twitterdata.columns
# Out:
# Index(['User', 'Username', 'UTC Date', 'Tweet', 'Permalink', 'Retweet count',
#        'Likes count', 'Tweet value', 'Sentiment', 'Day', 'Month'],
#       dtype='object')

# %%
# Count the number of tweets per day
df_tweets = df_twitterdata[['UTC Date']].copy()
df_tweets['Tweet Count'] = 1
df_tweets = df_tweets.resample('D', on='UTC Date').sum().reset_index()

# %%
# Prepare the data
data = df_tweets[['UTC Date', 'Tweet Count']].copy()
data.columns = ['ds', 'y']  # Rename the columns for Prophet

# %%
# Instantiate the Prophet model
model = Prophet()

# %%
# Fit the model with the historical data
model.fit(data)
# Out:
# 20:50:17 - cmdstanpy - INFO - Chain [1] start processing
# 20:50:17 - cmdstanpy - INFO - Chain [1] done processing

# %%
#future = model.make_future_dataframe(periods=7)  # Next week
#future = model.make_future_dataframe(periods=30)  # Next month
future = model.make_future_dataframe(periods=90)  # Next 3 months

# Generate predictions
forecast = model.predict(future)

# Plot the forecast
fig = model.plot(forecast, xlabel='Date', ylabel='Tweet Count')
plt.title('Tweet Count Forecast')

# Add observed data points
plt.scatter(data['ds'], data['y'], color='red', label='Observed')

# Add legend
plt.legend(loc='upper left')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet

# Count the number of tweets per day
df_tweets = df_twitterdata[['UTC Date']].copy()
df_tweets['Tweet Count'] = 1
df_tweets = df_tweets.resample('D', on='UTC Date').sum().reset_index()

# Prepare the data
data = df_tweets[['UTC Date', 'Tweet Count']].copy()
data.columns = ['ds', 'y']  # Rename the columns for Prophet

# Instantiate the Prophet model
model = Prophet()

# Fit the model with the historical data
model.fit(data)

# Make future dataframes for predictions
future_week = model.make_future_dataframe(periods=7)  # Next week
future_month = model.make_future_dataframe(periods=30)  # Next month
future_3months = model.make_future_dataframe(periods=90)  # Next 3 months

# Generate predictions for each future dataframe
forecast_week = model.predict(future_week)
forecast_month = model.predict(future_month)
forecast_3months = model.predict(future_3months)

# Plot the forecasts
fig, axs = plt.subplots(3, 1, figsize=(10, 15))

# Plot for next week
axs[0].plot(forecast_week['ds'], forecast_week['yhat'], label='Forecast')
axs[0].scatter(data['ds'], data['y'], color='red', label='Observed')
axs[0].set_xlabel('Date')
axs[0].set_ylabel('Tweet Count')
axs[0].set_title('Tweet Count Forecast - Next Week')
axs[0].legend(loc='upper left')

# Plot for next month
axs[1].plot(forecast_month['ds'], forecast_month['yhat'], label='Forecast')
axs[1].scatter(data['ds'], data['y'], color='red', label='Observed')
axs[1].set_xlabel('Date')
axs[1].set_ylabel('Tweet Count')
axs[1].set_title('Tweet Count Forecast - Next Month')
axs[1].legend(loc='upper left')

# Plot for next 3 months
axs[2].plot(forecast_3months['ds'], forecast_3months['yhat'], label='Forecast')
axs[2].scatter(data['ds'], data['y'], color='red', label='Observed')
axs[2].set_xlabel('Date')
axs[2].set_ylabel('Tweet Count')
axs[2].set_title('Tweet Count Forecast - Next 3 Months')
axs[2].legend(loc='upper left')

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 20:50:18 - cmdstanpy - INFO - Chain [1] start processing
# 20:50:18 - cmdstanpy - INFO - Chain [1] done processing

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# %%
# Count the number of tweets per day
df_tweets = df_twitterdata[['UTC Date']].copy()
df_tweets['Tweet Count'] = 1
df_tweets = df_tweets.resample('D', on='UTC Date').sum().reset_index()

# Set the 'UTC Date' column as the index
df_tweets.set_index('UTC Date', inplace=True)

# Split the data into training and testing sets
train_data = df_tweets.loc[:'2023-04-30']
test_data = df_tweets.loc['2023-05-01':]

# %%
# Define the ARIMA model
model = ARIMA(train_data, order=(1, 1, 1))

# Fit the model to the training data
model_fit = model.fit()
# Out:
# /home/hduser/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/hduser/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/hduser/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# Number of periods to forecast
forecast_periods = len(test_data)

# Generate predictions
predictions = model_fit.predict(start=len(train_data), end=len(train_data) + forecast_periods - 1)

# %%
# Calculate the mean squared error
mse = ((predictions - test_data['Tweet Count'].values) ** 2).mean()

# Print the mean squared error
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 45.22778985016568

# %%
#figure size
plt.figure(figsize=(12, 6)) 


# Combine the training and testing data
combined_data = pd.concat([train_data, test_data])


plt.plot(combined_data.index, combined_data.values, label='Observed')# Plot the observed data


plt.plot(test_data.index, predictions, label='Forecast')# Plot the forecasted values

# Set the x-axis label and title
plt.xlabel('Date')
plt.ylabel('Tweet Count')
plt.title('ARIMA Tweet Count Forecast')

plt.legend()
plt.show()

# %% [markdown]
# # # 1 month

# %%
train_data = df_tweets.iloc[:-30]  # Use data until 30 days before the end as training data
test_data = df_tweets.iloc[-30:]  # Use the last 30 days as testing data

# %%
model = ARIMA(train_data, order=(1, 1, 1))# Define the ARIMA model

model_fit = model.fit()# Fit the model to the training data
# Out:
# /home/hduser/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/hduser/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/hduser/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# Number of periods to forecast
forecast_periods = len(test_data)

predictions = model_fit.predict(start=len(train_data), end=len(train_data) + forecast_periods - 1)# Generate predictions

# %%
# Calculate the mean squared error
mse = ((predictions - test_data['Tweet Count'].values) ** 2).mean()

# Print the mean squared error
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 57.9246533915153

# %%
plt.figure(figsize=(12, 6))


combined_data = pd.concat([train_data, test_data])# Combine the training and testing data for plotting


plt.plot(combined_data.index, combined_data.values, label='Observed')# Plot the observed data


plt.plot(test_data.index, predictions, label='Forecast')# Plot the forecasted values

plt.xlabel('Date')
plt.ylabel('Tweet Count')
plt.title('ARIMA Tweet Count Forecast')

plt.legend()
plt.show()

# %% [markdown]
# ## 2 months

# %%
train_data = df_tweets.iloc[:-90]  # Use data until 30 days before the end as training data
test_data = df_tweets.iloc[-90:]  # Use the last 30 days as testing data

# %%
# Define the ARIMA model
model = ARIMA(train_data, order=(1, 1, 1))

# Fit the model to the training data
model_fit = model.fit()
# Out:
# /home/hduser/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/hduser/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/hduser/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
forecast_periods = len(test_data)
predictions = model_fit.predict(start=len(train_data), end=len(train_data) + forecast_periods - 1)

# %%
mse = ((predictions - test_data['Tweet Count'].values) ** 2).mean()# Calculate the mean squared error

print(f"Mean Squared Error: {mse}")# Print the mean squared error
# Out:
# Mean Squared Error: 69.56471002641312

# %%
plt.figure(figsize=(12, 6))  

# Combine the training and testing data for plotting
combined_data = pd.concat([train_data, test_data])


plt.plot(combined_data.index, combined_data.values, label='Observed')# Plot the observed data


plt.plot(test_data.index, predictions, label='Forecast')# Plot the forecasted values

plt.xlabel('Date')
plt.ylabel('Tweet Count')
plt.title('ARIMA Tweet Count Forecast')

plt.legend()
plt.show()

# %% [markdown]
# ## Dashboard using panel

# %%
#pip install panel
import panel as pn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def dayPlotPanel():
    fig, ax = plt.subplots(figsize=(6, 3))
    sns.countplot(data=df_twitterdata, x='Day')
    ax.set_xlabel('Day of Week')
    ax.set_ylabel('Tweet Count')
    ax.text(0.5, 1.05, 'Tweet Distribution by Day of Week', weight='bold', ha='center', transform=ax.transAxes)
    plt.close(fig)
    return fig

# %%
def monthPlotPanel():
    fig, ax = plt.subplots(figsize=(6, 3))
    sns.countplot(data=df_twitterdata, x='Month')
    ax.set_xlabel('Month of Tweet')
    ax.set_ylabel('Tweet Count')
    ax.text(0.5, 1.05, 'Tweet Distribution by Month of Tweet', weight='bold', ha='center', transform=ax.transAxes)
    plt.close(fig)
    return fig

# %%
def plot_category(category):
    fig, ax = plt.subplots()
    subset = data[data['Category'] == category]
    ax.bar(subset['Category'], subset['Value'])
    ax.set_xlabel('Category')
    ax.set_ylabel('Value')
    plt.close(fig)
    return fig

# %%
# Load Panel extension
pn.extension()

# Create a dropdown widget to select the plot
plot_options = ['ARIMA Plot','Day Plot', 'Month Plot' ]
plot_select = pn.widgets.Select(name='Select Plot', options=plot_options)

# Define the plot update function based on the selected option
def update_plot(plot_option):
    if plot_option == 'Day Plot':
        plot = dayPlotPanel()
    elif plot_option == 'Month Plot':
        plot = monthPlotPanel()
    elif plot_option == 'ARIMA Plot':
        plot = arima_plot(train_data, test_data, predictions) 
    else:
        plot = None
    return plot
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <div id='54f893aa-0637-49a6-8921-a85d6333051b'>
#   <div id="e6cb88c0-6057-43d2-8c99-390e707eaaa8" data-root-id="54f893aa-0637-49a6-8921-a85d6333051b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
def arima_plot(train_data, test_data, predictions):
    return fig

# Create a Panel Matplotlib widget to display the selected plot
plot_widget = pn.bind(update_plot, plot_option=plot_select)
plot_pane = pn.pane.Matplotlib(plot_widget)

# Create a dropdown widget to select the dataframe
dataset_options = ['DataFromDB', 'word Count', 'Hashtags', 'Words frequented Together']
dataset_select = pn.widgets.Select(name='Select Dataset', options=dataset_options)

# Define the dataset update function based on the selected option
def update_dataset(dataset_option):
    if dataset_option == 'DataFromDB':
        dataset = DataFromDB
    elif dataset_option == 'ordered_columns':
        dataset = ordered_columns
    elif dataset_option == 'hashtags':
        dataset = hashtags
    elif dataset_option == 'CoupledWords':
        dataset = CoupledWords  # Replace 'CoupledWords' with your actual dataset
    else:
        dataset = None
    return dataset

# %%
# Create a Panel DataFrame widget to display the selected dataset
dataset_widget = pn.bind(update_dataset, dataset_option=dataset_select)
dataset_pane = pn.pane.DataFrame(dataset_widget, width=400, height=800, sizing_mode='stretch_width')

# Create the dashboard layout
left_column = pn.Column(
    '# Day Plot',
    dayPlotPanel(),
    '# Month Plot',
    monthPlotPanel()
)

middle_column = pn.Column(
    '# Tweet Predictions',
    plot_select,
    plot_pane
)

right_column = pn.Column(
    '# Select Dataset',
    dataset_select,
    dataset_pane
)

dashboard = pn.Row(
    left_column,
    middle_column,
    right_column
)

plot_pane.sizing_mode = 'stretch_both'
plot_pane.height = 400

dashboard.show()
# Out:
# WARNING:param.DataFrame: Providing a width-responsive sizing_mode ('stretch_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# WARNING:param.Row: Providing a width-responsive sizing_mode ('stretch_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# Launching server at http://localhost:39951

# %%
dashboard_view = dashboard.servable()

dashboard_view.save('dashboard.html')

# %% [markdown]
# ## Old Twitter API - Unwanted Limited Historic Data

# %%
import requests
import json
import pandas as pd
from dotenv import dotenv_values
from tqdm import tqdm

# %%
#pip install python-dotenv
#!pip install tqdm

# %%
config = dotenv_values(".env")
bearer_token = config["BEARER_TOKEN"]

search_url = "https://api.twitter.com/2/tweets/search/recent"

query_params = {
    'query' : '(#party OR #partytime) lang:en -is:retweet since:2022-01-01 until:2022-12-31',
    'tweet.fields': 'author_id',
    'user.fields': 'name',
    "max_results":"100",
}


def bearer_oauth(r):
    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r

def connect_to_endpoint(url, params):
    response = requests.get(url, auth=bearer_oauth, params=params)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# Preparing the progress bar
pbar = tqdm(total=1000)  # Assuming we want 1000 tweets
tweets_data = []

while len(tweets_data) < 1000:  # Keep making requests until we have enough tweets
    json_response = connect_to_endpoint(search_url, query_params)
    tweets_data.extend(json_response['data'])
    pbar.update(len(json_response['data']))  # Update the progress bar
    query_params['pagination_token'] = json_response['meta']['next_token']  # Prepare for the next request

pbar.close()

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(tweets_data)

# Save DataFrame to CSV
df.to_csv('~/Downloads/tweets_data.csv', index=False)

print("Data saved to ~/Downloads/tweets_data.csv")

# %%
#my_api_keyconfig["API_KEY"]
from dotenv import dotenv_values

config = dotenv_values(".env")

#Twitter API key and API secret
my_api_key = config["API_KEY"]
my_api_key_secret = config["API_KEY_SECRET"]
